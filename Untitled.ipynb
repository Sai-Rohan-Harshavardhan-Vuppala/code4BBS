# %%
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json
import pandas as pd

url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'100',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': '497067f7-8fc3-4992-8591-dd0766512c96',
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  df=pd.DataFrame.from_dict(data["data"])
 
  
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)

# %%
df.head(100)
# Out:
#       id           name  symbol       slug  num_market_pairs  \
# 0      1        Bitcoin     BTC    bitcoin              9143
# 1   1027       Ethereum     ETH   ethereum              5494
# 2    825         Tether    USDT     tether             27739
# 3   1839            BNB     BNB        bnb               683
# 4   3408       USD Coin    USDC   usd-coin              2996
# ..   ...            ...     ...        ...               ...
# 95  2634    XDC Network     XDC     xinfin                50
# 96  2577      Ravencoin     RVN  ravencoin                93
# 97  8104  1inch Network   1INCH      1inch               203
# 98  5777         renBTC  RENBTC     renbtc                39
# 99  7455         Audius   AUDIO     audius                75
#
#                   date_added  \
# 0   2013-04-28T00:00:00.000Z
# 1   2015-08-07T00:00:00.000Z
# 2   2015-02-25T00:00:00.000Z
# 3   2017-07-25T00:00:00.000Z
# 4   2018-10-08T00:00:00.000Z
# ..                       ...
# 95  2018-04-12T00:00:00.000Z
# 96  2018-03-10T00:00:00.000Z
# 97  2020-12-25T00:00:00.000Z
# 98  2020-06-28T00:00:00.000Z
# 99  2020-10-20T00:00:00.000Z
#
#                                                  tags    max_supply  \
# 0   [mineable, pow, sha-256, store-of-value, state...  2.100000e+07
# 1   [mineable, pow, smart-contracts, ethereum-ecos...           NaN
# 2   [payments, stablecoin, asset-backed-stablecoin...           NaN
# 3   [marketplace, centralized-exchange, payments, ...  1.651168e+08
# 4   [medium-of-exchange, stablecoin, asset-backed-...           NaN
# ..                                                ...           ...
# 95                                                 []           NaN
# 96            [mineable, pow, platform, crowdfunding]  2.100000e+10
# 97  [decentralized-exchange, defi, amm, binance-sm...           NaN
# 98  [defi, binance-smart-chain, wrapped-tokens, fa...  1.369800e+04
# 99  [music, coinbase-ventures-portfolio, binance-l...           NaN
#
#     circulating_supply  total_supply  \
# 0         1.895555e+07  1.895555e+07
# 1         1.195472e+08  1.195472e+08
# 2         7.842305e+10  8.107470e+10
# 3         1.651168e+08  1.651168e+08
# 4         5.231365e+10  5.231365e+10
# ..                 ...           ...
# 95        1.230501e+10  3.770501e+10
# 96        1.047329e+10  1.047329e+10
# 97        4.157432e+08  1.500000e+09
# 98        1.625976e+04  1.625976e+04
# 99        6.083220e+08  1.078934e+09
#
#                                              platform  cmc_rank  \
# 0                                                None         1
# 1                                                None         2
# 2   {'id': 1027, 'name': 'Ethereum', 'symbol': 'ET...         3
# 3                                                None         4
# 4   {'id': 1027, 'name': 'Ethereum', 'symbol': 'ET...         5
# ..                                                ...       ...
# 95                                               None        96
# 96                                               None        97
# 97  {'id': 1027, 'name': 'Ethereum', 'symbol': 'ET...        98
# 98  {'id': 1027, 'name': 'Ethereum', 'symbol': 'ET...        99
# 99  {'id': 1027, 'name': 'Ethereum', 'symbol': 'ET...       100
#
#     self_reported_circulating_supply  self_reported_market_cap  \
# 0                                NaN                       NaN
# 1                                NaN                       NaN
# 2                                NaN                       NaN
# 3                                NaN                       NaN
# 4                                NaN                       NaN
# ..                               ...                       ...
# 95                               NaN                       NaN
# 96                               NaN                       NaN
# 97                      4.157432e+08              7.007562e+08
# 98                               NaN                       NaN
# 99                               NaN                       NaN
#
#                 last_updated  \
# 0   2022-02-12T09:27:00.000Z
# 1   2022-02-12T09:27:00.000Z
# 2   2022-02-12T09:27:00.000Z
# 3   2022-02-12T09:27:00.000Z
# 4   2022-02-12T09:27:00.000Z
# ..                       ...
# 95  2022-02-12T09:27:00.000Z
# 96  2022-02-12T09:27:00.000Z
# 97  2022-02-12T09:27:00.000Z
# 98  2022-02-12T09:27:00.000Z
# 99  2022-02-12T09:27:00.000Z
#
#                                                 quote
# 0   {'USD': {'price': 42335.088436026715, 'volume_...
# 1   {'USD': {'price': 2934.1805912056952, 'volume_...
# 2   {'USD': {'price': 1.0007428264311364, 'volume_...
# 3   {'USD': {'price': 401.44009656658824, 'volume_...
# 4   {'USD': {'price': 0.9996766956279464, 'volume_...
# ..                                                ...
# 95  {'USD': {'price': 0.059247234704942545, 'volum...
# 96  {'USD': {'price': 0.0671495854127837, 'volume_...
# 97  {'USD': {'price': 1.6855505719195838, 'volume_...
# 98  {'USD': {'price': 42074.01129039691, 'volume_2...
# 99  {'USD': {'price': 1.08488472426334, 'volume_24...
#
# [100 rows x 16 columns]
